# %%
import os
import re
from typing import Union, List, Tuple, Mapping

from aiida.common import exceptions
from aiida.common.lang import classproperty, type_check
from aiida.orm import Group, QueryBuilder
from aiida.plugins import DataFactory

from aiida_basis.data.basis import BasisData

__all__ = ('BasisSet',)

StructureData = DataFactory('structure')


class BasisSet(Group):
    """Group to represent a basis set.

    This is a base class that provides most of the functionality but does not actually define what type of basis
    can be contained. If ``_basis_types`` is not defined, any basis type is accepted in this
    basis set, as long as it is a subclass of ``BasisData``. Subclasses can limit which basis types can be
    hosted by setting ``_basis_types`` to a tuple of ``BasisData`` subclasses.
    """

    _key_basis_type = '_basis_type'
    _basis_types = (BasisData,)
    _bases = None

    def __repr__(self):
        """Represent the instance for debugging purposes."""
        return f'{self.__class__.__name__}<{self.pk or self.uuid}>'

    def __str__(self):
        """Represent the instance for human-readable purposes."""
        return f'{self.__class__.__name__}<{self.label}>'

    def __init__(self, *args, **kwargs):
        """Validate that the ``_basis_types`` class attribute is a tuple of ``BasisData`` subclasses."""
        if not self._basis_types or not isinstance(self._basis_types, tuple) or any(
            not issubclass(basis_type, BasisData) for basis_type in self._basis_types
        ):
            raise RuntimeError('`_basis_types` should be a tuple of `BasisData` subclasses.')
        basis_type = kwargs.pop('basis_type', None)
        dirpath = kwargs.pop('dirpath', None)
        super().__init__(*args, **kwargs)
        if dirpath:
            self._dirpath = dirpath
        self._basis_type = basis_type

    @classproperty
    def basis_types(cls):  # pylint: disable=no-self-argument
        """Return the basis types that this basis set accepts.

        :return: the tuple of subclasses of ``BasisData`` that this basis set can host nodes of. If it returns
            ``None``, that means all subclasses are supported.
        """
        return cls._basis_types

    @classmethod
    def _validate_basis_type(cls, basis_type):
        """Validate the ``basis_type`` passed to ``parse_bases_from_directory``.

        :return: the basis type to be used.
        """
        if basis_type is None and len(cls._basis_types) > 1:
            raise ValueError(f'`{cls}` supports more than one type, so `basis_type` needs to be explicitly passed.')

        basis_type = basis_type or cls._basis_types[0]

        if all(not issubclass(basis_type, supported_type) for supported_type in cls._basis_types):
            raise ValueError(f'`{basis_type}` is not supported by `{cls}`.')

        return basis_type

    @classmethod
    def _validate_dirpath(cls, dirpath):
        """Validate the ``dirpath`` passed to ``parse_bases_from_directory``.

        :return: the directory path to be used.
        """
        if not os.path.isdir(dirpath):
            raise ValueError(f'`{dirpath}` is not a directory')

        dirpath_contents = os.listdir(dirpath)

        if len(dirpath_contents) == 1 and os.path.isdir(os.path.join(dirpath, dirpath_contents[0])):
            dirpath = os.path.join(dirpath, dirpath_contents[0])

        return dirpath

    @classmethod
    def parse_bases_from_directory(cls, dirpath, basis_type=None, deduplicate=True):
        """Parse the basis files in the given directory into a list of data nodes.

        .. note:: The directory pointed to by `dirpath` should only contain basis files. Optionally, it can
            contain just a single directory, that contains all the basis files. If any other files are stored
            in the basepath or the subdirectory, that cannot be successfully parsed as basis files the method
            will raise a ``ValueError``.

        :param dirpath: absolute path to a directory containing bases.
        :param basis_type: subclass of ``BasisData`` to be used for the parsed bases. If not specified and
            the basis set only defines a single supported basis type in ``_basis_types`` then that will be used,
            otherwise a ``ValueError`` is raised.
        :param deduplicate: if True, will scan database for existing bases of same type and with the same
            md5 checksum, and use that instead of the parsed one.
        :return: list of data nodes
        :raises ValueError: if ``dirpath`` is not a directory or contains anything other than files.
        :raises ValueError: if ``dirpath`` contains multiple bases for the same element.
        :raises ValueError: if ``basis_type`` is explicitly specified and is not supported by this basis set class.
        :raises ValueError: if ``basis_type`` is not specified and the class supports more than one basis type.
        :raises ParsingError: if the constructor of the basis type fails for one of the files in the ``dirpath``.
        """
        from aiida.common.exceptions import ParsingError

        bases = []
        dirpath = cls._validate_dirpath(dirpath)
        basis_type = cls._validate_basis_type(basis_type)

        for filename in os.listdir(dirpath):
            filepath = os.path.join(dirpath, filename)

            if not os.path.isfile(filepath):
                raise ValueError(f'dirpath `{dirpath}` contains at least one entry that is not a file')

            with open(filepath, 'rb') as handle:
                try:
                    if deduplicate:
                        basis = basis_type.get_or_create(handle, filename=filename)
                    else:
                        basis = basis_type(handle, filename=filename)
                except ParsingError as exception:
                    raise ParsingError(f'failed to parse `{filepath}`: {exception}') from exception

            if basis.element is None:
                match = re.search(r'^([A-Za-z]{1,2})\.\w+', filename)
                if match is None:
                    raise ParsingError(
                        f'`{basis.__class__}` constructor did not define the element and could not parse a valid '
                        'element symbol from the filename `{filename}` either. It should have the format '
                        '`ELEMENT.EXTENSION`'
                    )
                basis.element = match.group(1)
            bases.append(basis)

        if not bases:
            raise ValueError(f'no bases were parsed from `{dirpath}`')

        elements = set(basis.element for basis in bases)

        if len(bases) != len(elements):
            raise ValueError(f'directory `{dirpath}` contains bases with duplicate elements')

        return bases

    @classmethod
    def create_from_folder(cls, dirpath, label, *, description='', basis_type=None, deduplicate=True):
        """Create a new ``BasisSet`` from the bases contained in a directory.

        :param dirpath: absolute path to the folder containing the UPF files.
        :param label: label to give to the ``BasisSet``, should not already exist.
        :param description: description to give to the basis set.
        :param basis_type: subclass of ``BasisData`` to be used for the parsed bases. If not specified and
            the basis set only defines a single supported basis type in ``_basis_types`` then that will be used,
            otherwise a ``ValueError`` is raised.
        :param deduplicate: if True, will scan database for existing bases of same type and with the same
            md5 checksum, and use that instead of the parsed one.
        :raises ValueError: if a ``BasisSet`` already exists with the given name.
        :raises ValueError: if ``dirpath`` is not a directory or contains anything other than files.
        :raises ValueError: if ``dirpath`` contains multiple bases for the same element.
        :raises ValueError: if ``basis_type`` is explicitly specified and is not supported by this basis set class.
        :raises ValueError: if ``basis_type`` is not specified and the class supports more than one basis type.
        :raises ParsingError: if the constructor of the basis type fails for one of the files in the ``dirpath``.
        """
        type_check(description, str, allow_none=True)

        try:
            cls.objects.get(label=label)
        except exceptions.NotExistent:
            basis_set = cls(label=label, description=description)
        else:
            raise ValueError(f'the {cls.__name__} `{label}` already exists')

        bases = cls.parse_bases_from_directory(dirpath, basis_type, deduplicate=deduplicate)

        # Only store the ``Group`` and the basis nodes now, such that we don't have to worry about the clean up in the
        # case that an exception is raised during creating them.
        basis_set.store()
        basis_set.add_nodes([basis.store() for basis in bases])

        return basis_set

    @property
    def basis_type(self):
        """Return the type of the bases that are hosted by this basis set.

        :return: the basis type or ``None`` if none has been set yet.
        """
        return self.get_extra(self._key_basis_type, None)

    def update_basis_type(self):
        """Update the basis type, stored as an extra, based on the current nodes in the basis set."""
        basis_types = {basis.__class__ for basis in self.bases.values()}

        if basis_types:
            assert len(basis_types) == 1, 'Basis set contains basis data nodes of various types.'
            entry_point_name = tuple(basis_types)[0].get_entry_point_name()
        else:
            entry_point_name = None

        self.set_extra(self._key_basis_type, entry_point_name)

    def add_nodes(self, nodes):
        """Add a node or a set of nodes to the basis set.

        .. note: Each basis set instance can only contain a single basis for each element.

        :param nodes: a single or list of ``Node`` instances of type that is in ``BasisSet._basis_types``.
        :raises ModificationNotAllowed: if the basis set is not stored.
        :raises TypeError: if nodes are not an instance or list of instance of any of the classes listed by
            ``BasisSet._basis_types``.
        :raises ValueError: if any of the nodes are not stored or their elements already exist in this basis set.
        """
        if not self.is_stored:
            raise exceptions.ModificationNotAllowed('cannot add nodes to an unstored group')

        if not isinstance(nodes, (list, tuple)):
            nodes = [nodes]

        if any(not isinstance(node, self._basis_types) for node in nodes):
            raise TypeError(f'only nodes of types `{self._basis_types}` can be added: {nodes}')

        bases = {}

        # Check for duplicates before adding any basis to the internal cache
        for basis in nodes:
            if basis.element in self.elements:
                raise ValueError(f'element `{basis.element}` already present in this basis set')
            bases[basis.element] = basis

        self.bases.update(bases)
        self.update_basis_type()

        super().add_nodes(nodes)

    def remove_nodes(self, nodes):
        """Remove a basis or a set of bases from the basis set.

        :param nodes: a single or list of ``BasisData`` instances or subclasses thereof.
        """
        super().remove_nodes(nodes)

        if not isinstance(nodes, (list, tuple)):
            nodes = (nodes,)

        removed = [node.pk for node in nodes]
        self._bases = {basis.element: basis for basis in self.bases.values() if basis.pk not in removed}
        self.update_basis_type()

    def clear(self):
        """Remove all the bases from this basis set."""
        super().clear()
        self._bases = None
        self.update_basis_type()

    @property
    def bases(self):
        """Return the dictionary of bases of this basis set indexed on the element symbol.

        :return: dictionary of element symbol mapping bases
        """
        if self._bases is None:
            self._bases = {basis.element: basis for basis in self.nodes}

        return self._bases

    @property
    def elements(self):
        """Return the list of elements for which this basis set defines a basis.

        :return: list of element symbols
        """
        return list(self.bases.keys())

    def get_basis(self, element):
        """Return the basis for the given element.

        :param element: the element for which to return the corresponding basis.
        :return: basis instance if it exists
        :raises ValueError: if the basis set does not contain a basis for the given element
        """
        try:
            basis = self.bases[element]
        except KeyError:
            builder = QueryBuilder()
            builder.append(self.__class__, filters={'id': self.pk}, tag='group')
            builder.append(self._basis_types, filters={'attributes.element': element}, with_group='group')

            try:
                basis = builder.one()[0]
            except exceptions.MultipleObjectsError as exception:
                raise RuntimeError(f'basis set `{self.label}` contains multiple bases for `{element}`') from exception
            except exceptions.NotExistent as exception:
                raise ValueError(
                    f'basis set `{self.label}` does not contain basis for element `{element}`'
                ) from exception
            else:
                self.bases[element] = basis

        return basis

    def get_bases(
        self,
        *,
        elements: Union[List[str], Tuple[str]] = None,  # pylint: disable=unsubscriptable-object
        structure: StructureData = None,
    ) -> Mapping[str, StructureData]:
        """Return the mapping of kind names on basis data nodes for the given list of elements or structure.

        :param elements: list of element symbols.
        :param structure: the ``StructureData`` node.
        :return: dictionary mapping the kind names of a structure on the corresponding basis data nodes.
        :raises ValueError: if the basis set does not contain a basis for any of the elements of the given structure.
        """
        if elements is not None and structure is not None:
            raise ValueError('cannot specify both keyword arguments `elements` and `structure`.')

        if elements is None and structure is None:
            raise ValueError('have to specify one of the keyword arguments `elements` and `structure`.')

        if elements is not None and not isinstance(elements, (list, tuple)) and not isinstance(elements, StructureData):
            raise ValueError('elements should be a list or tuple of symbols.')

        if structure is not None and not isinstance(structure, StructureData):
            raise ValueError('structure should be a `StructureData` instance.')

        if structure is not None:
            return {kind.name: self.get_basis(kind.symbol) for kind in structure.kinds}

        return {element: self.get_basis(element) for element in elements}

# %%
from aiida import load_profile
from aiida_basis.data.basis import PaoData
load_profile()
standard_19_soft_set = BasisSet(
    dirpath='./standard_19_soft/',
    label = 'OpenMX/19/standard/S',
    description='OpenMX standard 19 (soft)',
    basis_type=PaoData )
# Out:
# /home/t.hsu/miniconda3/envs/aiida-env/lib/python3.12/site-packages/aiida/plugins/entry_point.py:350: AiidaDeprecationWarning: The entry point `singlefile` is deprecated. Please replace it with `core.singlefile`. (this will be removed in v3)
#   warn_deprecation(f'The entry point `{name}` is deprecated. Please replace it with `core.{name}`.', version=3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 from aiida_basis.data.basis import PaoData
#       3 load_profile()
# ----> 4 standard_19_soft_set = BasisSet(
#       5     dirpath='./standard_19_soft/',
#       6     label = 'OpenMX/19/standard/S',
#       7     description='OpenMX standard 19 (soft)',
#       8     basis_type=PaoData )
#
# NameError: name 'BasisSet' is not defined

# %%
# !verdi group list -a
# Out:
# /home/t.hsu/miniconda3/envs/aiida-env/lib/python3.12/site-packages/aiida/plugins/entry_point.py:350: AiidaDeprecationWarning: The entry point `singlefile` is deprecated. Please replace it with `core.singlefile`. (this will be removed in v3)
#   warn_deprecation(f'The entry point `{name}` is deprecated. Please replace it with `core.{name}`.', version=3)
# /home/t.hsu/miniconda3/envs/aiida-env/lib/python3.12/site-packages/aiida/plugins/entry_point.py:350: AiidaDeprecationWarning: The entry point `structure` is deprecated. Please replace it with `core.structure`. (this will be removed in v3)
#   warn_deprecation(f'The entry point `{name}` is deprecated. Please replace it with `core.{name}`.', version=3)
#   PK  Label                 Type string    User
# ----  --------------------  -------------  ---------------
#    1  OpenMX/19/PBE/S       pseudo.family  aiida@localhost
#    2  OpenMX/19/standard/S  basis.set      aiida@localhost

# %%
from aiida_basis.groups.set import BasisSet
from aiida_basis.data.basis import PaoData
from aiida import load_profile
load_profile()
standard_19_soft_set = BasisSet(
    dirpath='./standard_19_soft/',
    label = 'OpenMX/19/standard/S',
    description='OpenMX standard 19 (soft)',
    basis_type=PaoData)

# standard_19_soft_set.store()
# Out:
# BasisSet<3>

# %%
import warnings

warnings.filterwarnings('ignore')
bases = BasisSet.parse_bases_from_directory('./standard_19_soft/', basis_type=PaoData)
print(f'Parsed bases: {[basis.element for basis in bases]}')
# Out:
# Ag11.0.pao
# Ag7.0.pao
# Ag9.0.pao
# Al7.0.pao
# Al8.0.pao
# Al9.0.pao
# Ar11.0.pao
# Ar9.0.pao
# As11.0.pao
# As7.0.pao
# As9.0.pao
# Au11.0.pao
# Au7.0.pao
# Au9.0.pao
# B7.0.pao
# B7.0_1s.pao
# B7.0_1s_CH.pao
# B8.0.pao
# B8.0_1s.pao
# B8.0_1s_CH.pao
# B9.0.pao
# B9.0_1s.pao
# B9.0_1s_CH.pao
# Ba10.0.pao
# Ba12.0.pao
# Ba14.0.pao
# Ba8.0.pao
# Be7.0.pao
# Be8.0.pao
# Be9.0.pao
# Bi10.0.pao
# Bi12.0.pao
# Bi8.0.pao
# Br7.0.pao
# Br8.0.pao
# Br9.0.pao
# C02.pao
# C5.0.pao
# C6.0.pao
# C6.0_1s.pao
# C6.0_1s_CH.pao
# C7.0.pao
# C7.0_1s.pao
# C7.0_1s_CH.pao
# Ca11.0.pao
# Ca13.0.pao
# Ca9.0.pao
# Cd11.0.pao
# Cd7.0.pao
# Cd9.0.pao
# Ce10.0.pao
# Ce12.0.pao
# Ce8.0.pao
# Cl7.0.pao
# Cl8.0.pao
# Cl9.0.pao
# Co10.0H.pao
# Co10.0S.pao
# Co6.0H.pao
# Co6.0S.pao
# Co8.0H.pao
# Co8.0S.pao
# Cr10.0.pao
# Cr6.0.pao
# Cr8.0.pao
# Cs12.0.pao
# Cs14.0.pao
# Cs16.0.pao
# Cu10.0H.pao
# Cu10.0S.pao
# Cu6.0H.pao
# Cu6.0S.pao
# Cu8.0H.pao
# Cu8.0S.pao
# Dy10.0.pao
# Dy10.0_OC.pao
# Dy12.0.pao
# Dy12.0_OC.pao
# Dy8.0.pao
# Dy8.0_OC.pao
# F5.0.pao
# F6.0.pao
# F7.0.pao
# Fe0.pao
# Fe10.0H.pao
# Fe10.0S.pao
# Fe4.0H.pao
# Fe5.0H.pao
# Fe5.0Hp.pao
# Fe5.0S.pao
# Fe5.0p.pao
# Fe5.5H.pao
# Fe5.5Hp.pao
# Fe5a_1.pao
# Fe5b_1.pao
# Fe6.0H.pao
# Fe6.0S.pao
# Fe8.0H.pao
# Fe8.0S.pao
# Ga7.0.pao
# Ga8.0.pao
# Ga9.0.pao
# Gd8.0_0.pao
# Gd8.0_1.pao
# Ge7.0.pao
# Ge7.0_3d.pao
# Ge7.0_3d_CH.pao
# Ge8.0.pao
# Ge8.0_3d.pao
# Ge8.0_3d_CH.pao
# Ge9.0.pao
# Ge9.0_3d.pao
# Ge9.0_3d_CH.pao
# H075.pao
# H5.0.pao
# H6.0.pao
# H7.0.pao
# He10.0.pao
# He8.0.pao
# Hf11.0.pao
# Hf7.0.pao
# Hf9.0.pao
# Hg10.0.pao
# Hg12.0.pao
# Hg8.0.pao
# Ho10.0.pao
# Ho12.0.pao
# Ho8.0.pao
# I11.0.pao
# I7.0.pao
# I9.0.pao
# In11.0.pao
# In7.0.pao
# In9.0.pao
# Ir11.0.pao
# Ir7.0.pao
# Ir9.0.pao
# K10.0.pao
# K12.0.pao
# K14.0.pao
# Kr10.0.pao
# Kr12.0.pao
# La10.0.pao
# La12.0.pao
# La8.0.pao
# Li10.0.pao
# Li12.0.pao
# Li8.0.pao
# Lu10.0.pao
# Lu12.0.pao
# Lu8.0.pao
# Mg11.0.pao
# Mg7.0.pao
# Mg9.0.pao
# Mn10.0.pao
# Mn6.0.pao
# Mn8.0.pao
# Mo11.0.pao
# Mo7.0.pao
# Mo9.0.pao
# N5.0.pao
# N6.0.pao
# N6.0p.pao
# N7.0.pao
# N8.0p.pao
# Na11.0.pao
# Na13.0.pao
# Na9.0.pao
# Nb11.0.pao
# Nb7.0.pao
# Nb9.0.pao
# Nd10.0.pao
# Nd10.0_OC.pao
# Nd12.0.pao
# Nd12.0_OC.pao
# Nd8.0.pao
# Nd8.0_OC.pao
# Ne11.0.pao
# Ne9.0.pao
# Ni10.0H.pao
# Ni10.0S.pao
# Ni2.pao
# Ni3.pao
# Ni4.pao
# Ni5.pao
# Ni6.0H.pao
# Ni6.0S.pao
# Ni6.0_2p.pao
# Ni6.0_2s.pao
# Ni6.pao
# Ni7.pao
# Ni8.0H.pao
# Ni8.0S.pao
# Ni8.pao
# Ni9.pao
# O5.0.pao
# O5.0_1s.pao
# O5.0_1s_CH.pao
# O6.0.pao
# O6.0_1s.pao
# O6.0_1s_CH.pao
# O7.0.pao
# O7.0_1s.pao
# O7.0_1s_CH.pao
# Os11.0.pao
# Os7.0.pao
# Os9.0.pao
# P7.0.pao
# P8.0.pao
# P9.0.pao
# Pb10.0.pao
# Pb12.0.pao
# Pb8.0.pao
# Pd11.0.pao
# Pd7.0.pao
# Pd9.0.pao
# Po10.0.pao
# Po12.0.pao
# Po8.0.pao
# Pt11.0.pao
# Pt7.0.pao
# Pt7.0_Sch.pao
# Pt9.0.pao
# Rb11.0.pao
# Rb13.0.pao
# Rb15.0.pao
# Re11.0.pao
# Re7.0.pao
# Re9.0.pao
# Rh11.0.pao
# Rh7.0.pao
# Rh9.0.pao
# Rn11.0.pao
# Rn13.0.pao
# Ru11.0.pao
# Ru7.0.pao
# Ru9.0.pao
# S0_7_1.pao
# S1_7_1.pao
# S7.0.pao
# S7.0_0.pao
# S7.0_1.pao
# S7.0_2p.pao
# S7.0_2p_CH.pao
# S8.0.pao
# S8.0_2p.pao
# S8.0_2p_CH.pao
# S9.0.pao
# S9.0_2p.pao
# S9.0_2p_CH.pao
# Sb11.0.pao
# Sb7.0.pao
# Sb9.0.pao
# Sc11.0.pao
# Sc7.0.pao
# Sc9.0.pao
# Se7.0.pao
# Se8.0.pao
# Se9.0.pao
# Si6.0p.pao
# Si7.0.pao
# Si7.0H.pao
# Si7.0_2p_CH.pao
# Si7.0_2p_p.pao
# Si7.0_SCH2p.pao
# Si8.0.pao
# Si8.0H.pao
# Si8.0_2p.pao
# Si8.0_2p_CH.pao
# Si8.0_SCH2p.pao
# Si9.0.pao
# Si9.0H.pao
# Si9.0_2p.pao
# Si9.0_SCH2p.pao
# Sm10.0.pao
# Sm10.0_OC.pao
# Sm12.0.pao
# Sm12.0_OC.pao
# Sm8.0.pao
# Sm8.0_OC.pao
# Sn11.0.pao
# Sn7.0.pao
# Sn9.0.pao
# Sr10.0.pao
# Sr12.0.pao
# Sr14.0.pao
# Ta11.0.pao
# Ta7.0.pao
# Ta9.0.pao
# Tc11.0.pao
# Tc7.0.pao
# Tc9.0.pao
# Te11.0.pao
# Te7.0.pao
# Te9.0.pao
# Ti11.0.pao
# Ti7.0.pao
# Ti9.0.pao
# Tl10.0.pao
# Tl12.0.pao
# Tl8.0.pao
# V10.0.pao
# V6.0.pao
# V8.0.pao
# W11.0.pao
# W7.0.pao
# W9.0.pao
# Xe11.0.pao
# Xe13.0.pao
# Y10.0.pao
# Y12.0.pao
# Y8.0.pao
# Zn10.0H.pao
# Zn10.0S.pao
# Zn6.0H.pao
# Zn6.0S.pao
# Zn8.0H.pao
# Zn8.0S.pao
# Zr11.0.pao
# Zr7.0.pao
# Zr9.0.pao
# Parsed bases: ['Ag', 'Ag', 'Ag', 'Al', 'Al', 'Al', 'Ar', 'Ar', 'As', 'As', 'As', 'Au', 'Au', 'Au', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'Ba', 'Ba', 'Ba', 'Ba', 'Be', 'Be', 'Be', 'Bi', 'Bi', 'Bi', 'Br', 'Br', 'Br', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Ca', 'Ca', 'Ca', 'Cd', 'Cd', 'Cd', 'Ce', 'Ce', 'Ce', 'Cl', 'Cl', 'Cl', 'Co', 'Co', 'Co', 'Co', 'Co', 'Co', 'Cr', 'Cr', 'Cr', 'Cs', 'Cs', 'Cs', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Dy', 'Dy', 'Dy', 'Dy', 'Dy', 'Dy', 'F', 'F', 'F', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Ga', 'Ga', 'Ga', 'Gd', 'Gd', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'X', 'H', 'H', 'H', 'He', 'He', 'Hf', 'Hf', 'Hf', 'Hg', 'Hg', 'Hg', 'Ho', 'Ho', 'Ho', 'I', 'I', 'I', 'In', 'In', 'In', 'Ir', 'Ir', 'Ir', 'K', 'K', 'K', 'Kr', 'Kr', 'La', 'La', 'La', 'Li', 'Li', 'Li', 'Lu', 'Lu', 'Lu', 'Mg', 'Mg', 'Mg', 'Mn', 'Mn', 'Mn', 'Mo', 'Mo', 'Mo', 'N', 'N', 'N', 'N', 'N', 'Na', 'Na', 'Na', 'Nb', 'Nb', 'Nb', 'Nd', 'Nd', 'Nd', 'Nd', 'Nd', 'Nd', 'Ne', 'Ne', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Os', 'Os', 'Os', 'P', 'P', 'P', 'Pb', 'Pb', 'Pb', 'Pd', 'Pd', 'Pd', 'Po', 'Po', 'Po', 'Pt', 'Pt', 'Pt', 'Pt', 'Rb', 'Rb', 'Rb', 'Re', 'Re', 'Re', 'Rh', 'Rh', 'Rh', 'Rn', 'Rn', 'Ru', 'Ru', 'Ru', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'Sb', 'Sb', 'Sb', 'Sc', 'Sc', 'Sc', 'Se', 'Se', 'Se', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Sm', 'Sm', 'Sm', 'Sm', 'Sm', 'Sm', 'Sn', 'Sn', 'Sn', 'Sr', 'Sr', 'Sr', 'Ta', 'Ta', 'Ta', 'Tc', 'Tc', 'Tc', 'Te', 'Te', 'Te', 'Ti', 'Ti', 'Ti', 'Tl', 'Tl', 'Tl', 'V', 'V', 'V', 'W', 'W', 'W', 'Xe', 'Xe', 'Y', 'Y', 'Y', 'Zn', 'Zn', 'Zn', 'Zn', 'Zn', 'Zn', 'Zr', 'Zr', 'Zr']

# %%
for basis in bases:
    if not basis.is_stored:
        basis.store()
        print(f'Stored basis for element {basis.element}')

# Load the group
basis_set_group = load_group(label='OpenMX/19/standard/S')

# Add the stored basis nodes to the group
basis_set_group.add_nodes(bases)
# Out:
# Stored basis for element Ag
# Stored basis for element Ag
# Stored basis for element Ag
# Stored basis for element Al
# Stored basis for element Al
# Stored basis for element Al
# Stored basis for element Ar
# Stored basis for element Ar
# Stored basis for element As
# Stored basis for element As
# Stored basis for element As
# Stored basis for element Au
# Stored basis for element Au
# Stored basis for element Au
# Stored basis for element B
# Stored basis for element B
# Stored basis for element B
# Stored basis for element B
# Stored basis for element B
# Stored basis for element B
# Stored basis for element B
# Stored basis for element B
# Stored basis for element B
# Stored basis for element Ba
# Stored basis for element Ba
# Stored basis for element Ba
# Stored basis for element Ba
# Stored basis for element Be
# Stored basis for element Be
# Stored basis for element Be
# Stored basis for element Bi
# Stored basis for element Bi
# Stored basis for element Bi
# Stored basis for element Br
# Stored basis for element Br
# Stored basis for element Br
# Stored basis for element C
# Stored basis for element C
# Stored basis for element C
# Stored basis for element C
# Stored basis for element C
# Stored basis for element C
# Stored basis for element C
# Stored basis for element C
# Stored basis for element Ca
# Stored basis for element Ca
# Stored basis for element Ca
# Stored basis for element Cd
# Stored basis for element Cd
# Stored basis for element Cd
# Stored basis for element Ce
# Stored basis for element Ce
# Stored basis for element Ce
# Stored basis for element Cl
# Stored basis for element Cl
# Stored basis for element Cl
# Stored basis for element Co
# Stored basis for element Co
# Stored basis for element Co
# Stored basis for element Co
# Stored basis for element Co
# Stored basis for element Co
# Stored basis for element Cr
# Stored basis for element Cr
# Stored basis for element Cr
# Stored basis for element Cs
# Stored basis for element Cs
# Stored basis for element Cs
# Stored basis for element Cu
# Stored basis for element Cu
# Stored basis for element Cu
# Stored basis for element Cu
# Stored basis for element Cu
# Stored basis for element Cu
# Stored basis for element Dy
# Stored basis for element Dy
# Stored basis for element Dy
# Stored basis for element Dy
# Stored basis for element Dy
# Stored basis for element Dy
# Stored basis for element F
# Stored basis for element F
# Stored basis for element F
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Fe
# Stored basis for element Ga
# Stored basis for element Ga
# Stored basis for element Ga
# Stored basis for element Gd
# Stored basis for element Gd
# Stored basis for element Ge
# Stored basis for element Ge
# Stored basis for element Ge
# Stored basis for element Ge
# Stored basis for element Ge
# Stored basis for element Ge
# Stored basis for element Ge
# Stored basis for element Ge
# Stored basis for element Ge
# Stored basis for element X
# Stored basis for element H
# Stored basis for element H
# Stored basis for element H
# Stored basis for element He
# Stored basis for element He
# Stored basis for element Hf
# Stored basis for element Hf
# Stored basis for element Hf
# Stored basis for element Hg
# Stored basis for element Hg
# Stored basis for element Hg
# Stored basis for element Ho
# Stored basis for element Ho
# Stored basis for element Ho
# Stored basis for element I
# Stored basis for element I
# Stored basis for element I
# Stored basis for element In
# Stored basis for element In
# Stored basis for element In
# Stored basis for element Ir
# Stored basis for element Ir
# Stored basis for element Ir
# Stored basis for element K
# Stored basis for element K
# Stored basis for element K
# Stored basis for element Kr
# Stored basis for element Kr
# Stored basis for element La
# Stored basis for element La
# Stored basis for element La
# Stored basis for element Li
# Stored basis for element Li
# Stored basis for element Li
# Stored basis for element Lu
# Stored basis for element Lu
# Stored basis for element Lu
# Stored basis for element Mg
# Stored basis for element Mg
# Stored basis for element Mg
# Stored basis for element Mn
# Stored basis for element Mn
# Stored basis for element Mn
# Stored basis for element Mo
# Stored basis for element Mo
# Stored basis for element Mo
# Stored basis for element N
# Stored basis for element N
# Stored basis for element N
# Stored basis for element N
# Stored basis for element N
# Stored basis for element Na
# Stored basis for element Na
# Stored basis for element Na
# Stored basis for element Nb
# Stored basis for element Nb
# Stored basis for element Nb
# Stored basis for element Nd
# Stored basis for element Nd
# Stored basis for element Nd
# Stored basis for element Nd
# Stored basis for element Nd
# Stored basis for element Nd
# Stored basis for element Ne
# Stored basis for element Ne
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element Ni
# Stored basis for element O
# Stored basis for element O
# Stored basis for element O
# Stored basis for element O
# Stored basis for element O
# Stored basis for element O
# Stored basis for element O
# Stored basis for element O
# Stored basis for element O
# Stored basis for element Os
# Stored basis for element Os
# Stored basis for element Os
# Stored basis for element P
# Stored basis for element P
# Stored basis for element P
# Stored basis for element Pb
# Stored basis for element Pb
# Stored basis for element Pb
# Stored basis for element Pd
# Stored basis for element Pd
# Stored basis for element Pd
# Stored basis for element Po
# Stored basis for element Po
# Stored basis for element Po
# Stored basis for element Pt
# Stored basis for element Pt
# Stored basis for element Pt
# Stored basis for element Pt
# Stored basis for element Rb
# Stored basis for element Rb
# Stored basis for element Rb
# Stored basis for element Re
# Stored basis for element Re
# Stored basis for element Re
# Stored basis for element Rh
# Stored basis for element Rh
# Stored basis for element Rh
# Stored basis for element Rn
# Stored basis for element Rn
# Stored basis for element Ru
# Stored basis for element Ru
# Stored basis for element Ru
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element S
# Stored basis for element Sb
# Stored basis for element Sb
# Stored basis for element Sb
# Stored basis for element Sc
# Stored basis for element Sc
# Stored basis for element Sc
# Stored basis for element Se
# Stored basis for element Se
# Stored basis for element Se
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Si
# Stored basis for element Sm
# Stored basis for element Sm
# Stored basis for element Sm
# Stored basis for element Sm
# Stored basis for element Sm
# Stored basis for element Sm
# Stored basis for element Sn
# Stored basis for element Sn
# Stored basis for element Sn
# Stored basis for element Sr
# Stored basis for element Sr
# Stored basis for element Sr
# Stored basis for element Ta
# Stored basis for element Ta
# Stored basis for element Ta
# Stored basis for element Tc
# Stored basis for element Tc
# Stored basis for element Tc
# Stored basis for element Te
# Stored basis for element Te
# Stored basis for element Te
# Stored basis for element Ti
# Stored basis for element Ti
# Stored basis for element Ti
# Stored basis for element Tl
# Stored basis for element Tl
# Stored basis for element Tl
# Stored basis for element V
# Stored basis for element V
# Stored basis for element V
# Stored basis for element W
# Stored basis for element W
# Stored basis for element W
# Stored basis for element Xe
# Stored basis for element Xe
# Stored basis for element Y
# Stored basis for element Y
# Stored basis for element Y
# Stored basis for element Zn
# Stored basis for element Zn
# Stored basis for element Zn
# Stored basis for element Zn
# Stored basis for element Zn
# Stored basis for element Zn
# Stored basis for element Zr
# Stored basis for element Zr
# Stored basis for element Zr

# %%
from aiida.orm import Group, load_group

# Load the group by its label
basis_set_group = load_group(label='OpenMX/19/standard/S')

# Check the type of the group
print(f'Group type: {basis_set_group.type_string}')

# List all nodes (i.e., bases) in the group
basis_nodes = basis_set_group.nodes
print(f'Number of bases in the group: {len(basis_nodes)}')

# Print the elements of all bases in the group
elements = [node.element for node in basis_nodes]
print(f'Elements in the BasisSet: {elements}')

# Check if the desired element ('Si') is in the BasisSet
if 'Si' in elements:
    print("The BasisSet contains information for element 'Si'.")
else:
    print("The BasisSet does NOT contain information for element 'Si'.")
# Out:
# Group type: basis.set
# Number of bases in the group: 321
# Elements in the BasisSet: ['Ag', 'Ag', 'Ag', 'Al', 'Al', 'Al', 'Ar', 'Ar', 'As', 'As', 'As', 'Au', 'Au', 'Au', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'Ba', 'Ba', 'Ba', 'Ba', 'Be', 'Be', 'Be', 'Bi', 'Bi', 'Bi', 'Br', 'Br', 'Br', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Ca', 'Ca', 'Ca', 'Cd', 'Cd', 'Cd', 'Ce', 'Ce', 'Ce', 'Cl', 'Cl', 'Cl', 'Co', 'Co', 'Co', 'Co', 'Co', 'Co', 'Cr', 'Cr', 'Cr', 'Cs', 'Cs', 'Cs', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Dy', 'Dy', 'Dy', 'Dy', 'Dy', 'Dy', 'F', 'F', 'F', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Ga', 'Ga', 'Ga', 'Gd', 'Gd', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'Ge', 'X', 'H', 'H', 'H', 'He', 'He', 'Hf', 'Hf', 'Hf', 'Hg', 'Hg', 'Hg', 'Ho', 'Ho', 'Ho', 'I', 'I', 'I', 'In', 'In', 'In', 'Ir', 'Ir', 'Ir', 'K', 'K', 'K', 'Kr', 'Kr', 'La', 'La', 'La', 'Li', 'Li', 'Li', 'Lu', 'Lu', 'Lu', 'Mg', 'Mg', 'Mg', 'Mn', 'Mn', 'Mn', 'Mo', 'Mo', 'Mo', 'N', 'N', 'N', 'N', 'N', 'Na', 'Na', 'Na', 'Nb', 'Nb', 'Nb', 'Nd', 'Nd', 'Nd', 'Nd', 'Nd', 'Nd', 'Ne', 'Ne', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'Ni', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Os', 'Os', 'Os', 'P', 'P', 'P', 'Pb', 'Pb', 'Pb', 'Pd', 'Pd', 'Pd', 'Po', 'Po', 'Po', 'Pt', 'Pt', 'Pt', 'Pt', 'Rb', 'Rb', 'Rb', 'Re', 'Re', 'Re', 'Rh', 'Rh', 'Rh', 'Rn', 'Rn', 'Ru', 'Ru', 'Ru', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'Sb', 'Sb', 'Sb', 'Sc', 'Sc', 'Sc', 'Se', 'Se', 'Se', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Si', 'Sm', 'Sm', 'Sm', 'Sm', 'Sm', 'Sm', 'Sn', 'Sn', 'Sn', 'Sr', 'Sr', 'Sr', 'Ta', 'Ta', 'Ta', 'Tc', 'Tc', 'Tc', 'Te', 'Te', 'Te', 'Ti', 'Ti', 'Ti', 'Tl', 'Tl', 'Tl', 'V', 'V', 'V', 'W', 'W', 'W', 'Xe', 'Xe', 'Y', 'Y', 'Y', 'Zn', 'Zn', 'Zn', 'Zn', 'Zn', 'Zn', 'Zr', 'Zr', 'Zr']
# The BasisSet contains information for element 'Si'.

# %%
from aiida.orm import load_group
family = load_group('OpenMX/19/standard/S')
pseudo = family.get_basis(element='Ga')  # Returns a single basis
pseudos = family.get_bases(elements=('Ga', 'As'))  # Returns a dictionary where the keys are the elements

# %%
BasisSet.get_basis(bases[0].element,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 BasisSet.get_basis('Ag')
#
# TypeError: BasisSet.get_basis() missing 1 required positional argument: 'element'

# %%
# !verdi group list -a
# !verdi node list
# Out:
# /home/t.hsu/miniconda3/envs/aiida-env/lib/python3.12/site-packages/aiida/plugins/entry_point.py:350: AiidaDeprecationWarning: The entry point `singlefile` is deprecated. Please replace it with `core.singlefile`. (this will be removed in v3)
#   warn_deprecation(f'The entry point `{name}` is deprecated. Please replace it with `core.{name}`.', version=3)
# /home/t.hsu/miniconda3/envs/aiida-env/lib/python3.12/site-packages/aiida/plugins/entry_point.py:350: AiidaDeprecationWarning: The entry point `structure` is deprecated. Please replace it with `core.structure`. (this will be removed in v3)
#   warn_deprecation(f'The entry point `{name}` is deprecated. Please replace it with `core.{name}`.', version=3)
#   PK  Label                 Type string    User
# ----  --------------------  -------------  ---------------
#    1  OpenMX/19/PBE/S       pseudo.family  aiida@localhost
#    2  OpenMX/19/standard/S  basis.set      aiida@localhost
#   id  uuid                                  node_type
# ----  ------------------------------------  ------------------------
#    1  579d480f-9dab-4da8-bfc1-2f743be2cf3c  data.pseudo.vps.VpsData.
#    2  f0295445-c218-4c86-9e65-b03efaaeff62  data.pseudo.vps.VpsData.
#    3  8191fcab-f6dc-4e3d-a8ae-9c05b33dd678  data.pseudo.vps.VpsData.
#    4  0e3919f0-c61d-48ce-9c47-d40609acfcdf  data.pseudo.vps.VpsData.
#    5  d4c2ac71-8204-44cb-8364-212fbfa97e89  data.pseudo.vps.VpsData.
#    6  c824e1f7-e54e-4778-9606-f385a4543b8a  data.pseudo.vps.VpsData.
#    7  0fdf715e-61f5-4868-ac06-014b2b818f31  data.pseudo.vps.VpsData.
#    8  004d54dd-6acc-495c-b73b-7fd8dfcb9b8a  data.pseudo.vps.VpsData.
#    9  d93e5758-1953-40b5-9e55-f8feecbfb85f  data.pseudo.vps.VpsData.
#   10  c6c7d199-7190-4f6d-9ba5-8578ac5889dd  data.pseudo.vps.VpsData.
#   11  e6d2e14a-836e-4782-8965-054d2f33ebd0  data.pseudo.vps.VpsData.
#   12  fee40067-592c-4819-b308-335ca72bb379  data.pseudo.vps.VpsData.
#   13  215f0694-0ca3-4ab2-9419-ab24abcf2e22  data.pseudo.vps.VpsData.
#   14  2fb9a2d2-2610-439d-88bc-51bd46e346ba  data.pseudo.vps.VpsData.
#   15  c474fa93-e94e-4a41-867f-3cbf8397019d  data.pseudo.vps.VpsData.
#   16  2456fb12-1d08-42ef-86c5-ec3b2ea0fbe0  data.pseudo.vps.VpsData.
#   17  7e421c5d-25f4-4876-95d8-cfff409cfdaa  data.pseudo.vps.VpsData.
#   18  3c761c54-32fd-48da-855d-ca87fde6e8af  data.pseudo.vps.VpsData.
#   19  9f9f9bb8-3afe-4cf7-9d5e-22576cda6707  data.pseudo.vps.VpsData.
#   20  ae82aeb1-763c-4bee-8cb7-c79dc0115fe1  data.pseudo.vps.VpsData.
#   21  fd2b9d01-1782-42e3-92bc-81c6682c9c98  data.pseudo.vps.VpsData.
#   22  7896420e-a5dc-4107-aba8-fb9e345c2375  data.pseudo.vps.VpsData.
#   23  cee7dd39-14fa-4a38-9af9-2ddb7f64a799  data.pseudo.vps.VpsData.
#   24  dc5df82e-6c0a-46f6-9008-88dd1dd8caa3  data.pseudo.vps.VpsData.
#   25  e99dada7-d921-4110-850d-4e1f4c45be84  data.pseudo.vps.VpsData.
#   26  e855fadd-08ba-4a38-aca2-311eff7a76f3  data.pseudo.vps.VpsData.
#   27  48bc528b-7f8b-44df-a988-12c3a54bf4fc  data.pseudo.vps.VpsData.
#   28  d6238574-12b2-4054-b051-eae801ff560a  data.pseudo.vps.VpsData.
#   29  c4b7df35-dda9-4a40-a75f-e6588c6600e7  data.pseudo.vps.VpsData.
#   30  eb3c7fb3-6d46-44dd-8710-0f6deef4f51a  data.pseudo.vps.VpsData.
#   31  29020f1d-5814-40e6-a467-c9e290d3239d  data.pseudo.vps.VpsData.
#   32  b8be76c5-ce36-4966-b530-1a9a3019639d  data.pseudo.vps.VpsData.
#   33  95dd5d17-c94c-4da1-9419-096c5e9b7e7e  data.pseudo.vps.VpsData.
#   34  e7bdfa95-830a-45dd-8cbb-5188a781b395  data.pseudo.vps.VpsData.
#   35  dee4be4c-cf68-4ee8-ab07-6b42fa22084c  data.pseudo.vps.VpsData.
#   36  d4d3d38f-4c8d-4b5a-afd9-fd1ed73c5da5  data.pseudo.vps.VpsData.
#   37  8ff3bab1-3bc6-486d-917c-4266629debd2  data.pseudo.vps.VpsData.
#   38  6ead578c-fe98-44af-8ae3-82fed4c9596b  data.pseudo.vps.VpsData.
#   39  f6040835-f3c6-42dd-bd7c-b878408a37ea  data.pseudo.vps.VpsData.
#   40  1b5cb9b5-07aa-4376-b36f-1c00d64e24bb  data.pseudo.vps.VpsData.
#   41  295e8622-6c76-4a54-bcd7-33f37e3a4185  data.pseudo.vps.VpsData.
#   42  af6a4766-6937-4dc0-be3f-4124d3cfed85  data.pseudo.vps.VpsData.
#   43  222d7a44-476d-42fb-bf63-b82ddcce7f23  data.pseudo.vps.VpsData.
#   44  c5d67d18-f134-4637-b5ef-271b95d6ba9b  data.pseudo.vps.VpsData.
#   45  5e4714ec-efdd-47a5-b275-5a37dba42c44  data.pseudo.vps.VpsData.
#   46  e749a923-41f5-41df-aacb-59e420a86e84  data.pseudo.vps.VpsData.
#   47  b4cef064-79fb-4c17-a6a5-6074cf8114a1  data.pseudo.vps.VpsData.
#   48  85f14667-204b-45f5-91e3-1d147cdb6fc9  data.pseudo.vps.VpsData.
#   49  24909784-a57d-40d7-813f-91326cb2e0ad  data.pseudo.vps.VpsData.
#   50  8ace0496-162b-48f5-aaa5-ae90ce5e329c  data.pseudo.vps.VpsData.
#   51  f532667b-d66a-40b0-932c-b50efa42a0f7  data.pseudo.vps.VpsData.
#   52  4d3a14fc-c09c-4475-9fe5-39e1e0465579  data.pseudo.vps.VpsData.
#   53  49505781-331a-4749-a96d-83fde156bbf6  data.pseudo.vps.VpsData.
#   54  1582da95-25d1-476d-810e-71fedb74e559  data.pseudo.vps.VpsData.
#   55  70f54912-481a-4fd3-99a9-12955a2b4ea7  data.pseudo.vps.VpsData.
#   56  51d5086d-ee02-476b-b14c-36fddffbc67d  data.pseudo.vps.VpsData.
#   57  c4444e84-baf9-495d-9ecc-9588954a43fb  data.pseudo.vps.VpsData.
#   58  a05274b6-6efc-41a0-9f0b-8e177b38d412  data.pseudo.vps.VpsData.
#   59  3c84d29a-e4d7-4ad1-b97e-95a9edc73de3  data.pseudo.vps.VpsData.
#   60  96c4b15f-8c7e-40f9-aa43-16f9ccab628c  data.pseudo.vps.VpsData.
#   61  ec09c77c-dfab-4673-a8bd-cc75b312b2c6  data.pseudo.vps.VpsData.
#   62  3ba29cfc-9245-4319-9f3c-4728ba24b1f7  data.pseudo.vps.VpsData.
#   63  83457c61-bdcd-4e71-b562-8393dc7065e7  data.pseudo.vps.VpsData.
#   64  848eeb1a-63d1-40bf-9f45-65a94658f9ab  data.pseudo.vps.VpsData.
#   65  0652dc56-6d00-4fb0-980f-e77dcc7293e0  data.pseudo.vps.VpsData.
#   66  60e2e1d2-cc9d-43b6-a330-d1226a10f763  data.pseudo.vps.VpsData.
#   67  4784f5ee-e186-45cd-9d17-5887c1a4ac40  data.pseudo.vps.VpsData.
#   68  41760af4-c4c4-4d20-acef-c003f077fb62  data.pseudo.vps.VpsData.
#   69  cfa99fdd-ea05-4d9b-9123-211aa9b10923  data.pseudo.vps.VpsData.
#   70  b1d9812f-a0fc-4690-9cb6-26efd79baa2b  data.pseudo.vps.VpsData.
#   71  f9e4ae5e-ce44-4200-830e-e66ae3bae61f  data.pseudo.vps.VpsData.
#   72  e5178073-5a2e-45f9-8302-c4c7a7ca783b  data.pseudo.vps.VpsData.
#   73  b4199897-2802-426b-a7fa-40f7e6e590a0  data.pseudo.vps.VpsData.
#   74  445bb802-0b0d-4d5f-a8e2-4cb7706a8358  data.pseudo.vps.VpsData.
#   75  1d68eba9-209a-4ec4-a44a-549a9b9f70c1  data.pseudo.vps.VpsData.
#   76  279050d0-c6c0-41fb-a295-1d5c8c53a9fd  data.pseudo.vps.VpsData.
#   77  2f758dca-ce74-49ff-85d7-60de416d7da4  data.pseudo.vps.VpsData.

# %%
from aiida.orm import Group

# Query the group by label
group = Group.get(label='OpenMX/19/standard/S')

# Print the group details
print(f'Group label: {group.label}')
print(f'Description: {group.description}')
# Out:
# Group label: OpenMX/19/standard/S
# Description: OpenMX standard 19 (soft)
# /home/t.hsu/miniconda3/envs/aiida-env/lib/python3.12/site-packages/aiida/orm/entities.py:227: AiidaDeprecationWarning: `Group.get` method is deprecated, use `Group.collection.get` instead. (this will be removed in v3)
#   warn_deprecation(

# %%
# Out:
# /home/t.hsu/miniconda3/envs/aiida-env/lib/python3.12/site-packages/aiida/orm/entities.py:227: AiidaDeprecationWarning: `BasisSet.get` method is deprecated, use `BasisSet.collection.get` instead. (this will be removed in v3)
#   warn_deprecation(
